# %% [markdown]
# Data Science Capstone Project Week 3

# %% [markdown]
# Download and import necessaary libraries

# %%
# import needed libraries
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import csv
#!conda install -c conda-forge folium=0.5.0 --yes 
from pandas.io.json import json_normalize
import folium
import numpy as np
from sklearn.cluster import KMeans
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
import functools

# %% [markdown]
# Foursquare Credentials

# %%
# Foursquare credentials 
CLIENT_ID = 'OEKMEBXITJT02VBZB3LP4ATYZ35OI3PLISMSZUTSJSFMBZQI'
CLIENT_SECRET = 'POCWPILITAHTRCVJB1EKV1Y1OM30PZXOGVYAPZ4CCPZKHMUQ'
VERSION = '20180605' 
LIMIT = 100
# Out:
# Your credentails:
# CLIENT_ID: OEKMEBXITJT02VBZB3LP4ATYZ35OI3PLISMSZUTSJSFMBZQI
# CLIENT_SECRET:POCWPILITAHTRCVJB1EKV1Y1OM30PZXOGVYAPZ4CCPZKHMUQ

# %%
url = "https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=1008658788"
#url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html_content = requests.get(url).text
soup = bs(html_content, "lxml")

# %%
table = soup.find("table", attrs={"class": "wikitable"})
#print(soup)
# identify columns
th = table.find_all("th")
headers = []
for x in th:
    headers.append(x.text.strip())

# identify rows  
tr = table.find_all("tr")
rows = []

# split elements into lists and remove empty elements
for x in tr[1:]:
    rows.append(x.text.split("\n"))
for x in rows:
    for y in x:
        x.remove('')

# %%
df = pd.DataFrame(rows, columns = headers) 
df = df[df.Borough != 'Not assigned']
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %%
#Download and read the csv file containing coordinates 
url = "https://cocl.us/Geospatial_data"
coords = pd.read_csv(url)

# %%
#Merge coordinates with boroughs dataframe
df_coords= df.merge(coords, on="Postal Code")
df_coords.head(20)
# Out:
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                           Regent Park, Harbourfront  43.654260 -79.360636
# 3                    Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 5             Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 6                                      Malvern, Rouge  43.806686 -79.194353
# 7                                           Don Mills  43.745906 -79.352188
# 8                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 9                            Garden District, Ryerson  43.657162 -79.378937
# 10                                          Glencairn  43.709577 -79.445073
# 11  West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 12             Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 13                                          Don Mills  43.725900 -79.340923
# 14                                   Woodbine Heights  43.695344 -79.318389
# 15                                     St. James Town  43.651494 -79.375418
# 16                                 Humewood-Cedarvale  43.693781 -79.428191
# 17  Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 18                  Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                        The Beaches  43.676357 -79.293031

# %%
neighborhood_latitude=df_coords.loc[0, 'Latitude'] 
neighborhood_longitude=df_coords.loc[0, 'Longitude']

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=OEKMEBXITJT02VBZB3LP4ATYZ35OI3PLISMSZUTSJSFMBZQI&client_secret=POCWPILITAHTRCVJB1EKV1Y1OM30PZXOGVYAPZ4CCPZKHMUQ&v=20180605&ll=43.7532586,-79.3296565&radius=500&limit=100'

# %%
results = requests.get(url).json()
# Out:
# {'meta': {'code': 200, 'requestId': '608865da75caea17dc10f165'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Parkwoods - Donalda',
#   'headerFullLocation': 'Parkwoods - Donalda, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 3,
#   'suggestedBounds': {'ne': {'lat': 43.757758604500005,
#     'lng': -79.32343823984928},
#    'sw': {'lat': 43.7487585955, 'lng': -79.33587476015072}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8d9dcdd5fbbbb6b3003c7b',
#        'name': 'Brookbanks Park',
#        'location': {'address': 'Toronto',
#         'lat': 43.751976046055574,
#         'lng': -79.33214044722958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.751976046055574,
#           'lng': -79.33214044722958}],
#         'distance': 245,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '600917367'}},
#       'referralId': 'e-0-4e8d9dcdd5fbbbb6b3003c7b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fc825cac5b8dd60907c56b3',
#        'name': 'Towns On The Ravine',
#        'location': {'address': '35 Valley Woods Road',
#         'lat': 43.7547545,
#         'lng': -79.3325523,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7547545,
#           'lng': -79.3325523}],
#         'distance': 286,
#         'postalCode': 'M3A 2R5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['35 Valley Woods Road',
#          'Toronto ON M3A 2R5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359110116'}},
#       'referralId': 'e-0-5fc825cac5b8dd60907c56b3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb11e2075ebb60cd1c4caad',
#        'name': 'Variety Store',
#        'location': {'address': '29 Valley Woods Road',
#         'lat': 43.75197441585782,
#         'lng': -79.33311418516017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75197441585782,
#           'lng': -79.33311418516017}],
#         'distance': 312,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['29 Valley Woods Road', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'shortName': 'Food & Drink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb11e2075ebb60cd1c4caad-2'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                   name         categories        lat        lng
# 0      Brookbanks Park               Park  43.751976 -79.332140
# 1  Towns On The Ravine              Hotel  43.754754 -79.332552
# 2        Variety Store  Food & Drink Shop  43.751974 -79.333114

# %%
if "cached_requests_get" not in dir():
    @functools.lru_cache(maxsize=10000)
    def cached_requests_get(url):
        for _ in range(5):
            response = requests.get(url)
            json = response.json()
            if json["meta"]["code"] == 500:
                time.sleep(5)
            else:
                return response

# %%
venues_list=[]
LIMIT = 100
radius = 1000 


def getNearbyVenues(names, latitudes, longitudes, radius=500):
    global venues_list
    venues_list=[]
    
   
    for name, lat, lng in zip(names, latitudes, longitudes):

        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        request_json = cached_requests_get(url).json()
        results = request_json["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Neighborhood_venues = getNearbyVenues(names=df_coords['Neighbourhood'],
                                   latitudes=df_coords['Latitude'],
                                   longitudes=df_coords['Longitude']
                                    )

# %%
# getting dummies
Toronto_dummies = pd.get_dummies(Neighborhood_venues[['Venue Category']], prefix="", prefix_sep="")
Toronto_dummies = Toronto_dummies.drop('Neighborhood', axis=1)
Toronto_dummies.insert(1,'Neighborhood',Neighborhood_venues['Neighborhood'] )

# grouping dataframe
Toronto_grouped = Toronto_dummies.groupby('Neighborhood').mean().reset_index()

# %%
# sort in descending order function
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

#workaround to avoid key error NO NEED ANYMORE
#neighborhoods_venues_sorted['Neighborhood'] = first_column

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                        Agincourt                Lounge
# 1                           Alderwood, Long Branch           Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North                  Bank
# 3                                  Bayview Village                  Café
# 4                Bedford Park, Lawrence Manor East        Sandwich Place
#
#        2nd Most Common Venue 3rd Most Common Venue    4th Most Common Venue  \
# 0  Latin American Restaurant        Breakfast Spot             Skating Rink
# 1                        Gym                   Pub           Sandwich Place
# 2                Coffee Shop     Mobile Phone Shop              Supermarket
# 3                       Bank   Japanese Restaurant       Chinese Restaurant
# 4         Italian Restaurant           Coffee Shop  Comfort Food Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0             Drugstore        Discount Store   Distribution Center
# 1           Coffee Shop            Playground          Skating Rink
# 2      Sushi Restaurant            Restaurant        Ice Cream Shop
# 3           Yoga Studio   Distribution Center               Dog Run
# 4       Thai Restaurant  Fast Food Restaurant             Juice Bar
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0               Dog Run      Doner Restaurant             Donut Shop
# 1    Dim Sum Restaurant                 Diner         Discount Store
# 2         Deli / Bodega                 Diner    Fried Chicken Joint
# 3      Doner Restaurant            Donut Shop              Drugstore
# 4               Butcher                  Café             Restaurant

# %%
# set number of clusters
kclusters = 10

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 1, 3, 1, 3, 3, 3, 3, 3, 3])

# %%
# add clustering labels, clean up dataframe
neighborhoods_venues_sorted.insert(1, 'Cluster Labels', kmeans.labels_)
Toronto_merged = df_coords.copy()
Toronto_merged.rename(columns={'Neighbourhood': 'Neighborhood'},inplace=True)
#Toronto_merged.drop('Postal Code',axis=1,inplace=True)


# merge clusters and venues
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged['Cluster Labels'].replace(float("NaN"),kclusters,inplace = True)
Toronto_merged.head(20)
# Out:
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                           Regent Park, Harbourfront  43.654260 -79.360636
# 3                    Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 5             Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 6                                      Malvern, Rouge  43.806686 -79.194353
# 7                                           Don Mills  43.745906 -79.352188
# 8                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 9                            Garden District, Ryerson  43.657162 -79.378937
# 10                                          Glencairn  43.709577 -79.445073
# 11  West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 12             Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 13                                          Don Mills  43.725900 -79.340923
# 14                                   Woodbine Heights  43.695344 -79.318389
# 15                                     St. James Town  43.651494 -79.375418
# 16                                 Humewood-Cedarvale  43.693781 -79.428191
# 17  Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 18                  Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                        The Beaches  43.676357 -79.293031
#
#     Cluster Labels 1st Most Common Venue   2nd Most Common Venue  \
# 0              3.0     Food & Drink Shop                    Park
# 1              3.0          Hockey Arena       French Restaurant
# 2              3.0           Coffee Shop                    Café
# 3              3.0        Clothing Store  Furniture / Home Store
# 4              3.0           Coffee Shop        Sushi Restaurant
# 5             10.0                   NaN                     NaN
# 6              6.0  Fast Food Restaurant               Drugstore
# 7              3.0                   Gym             Coffee Shop
# 8              1.0           Pizza Place                Pharmacy
# 9              3.0           Coffee Shop          Clothing Store
# 10             1.0                  Park             Pizza Place
# 11            10.0                   NaN                     NaN
# 12             2.0                   Bar             Yoga Studio
# 13             3.0                   Gym             Coffee Shop
# 14             3.0          Skating Rink            Intersection
# 15             3.0           Coffee Shop                    Café
# 16             3.0          Hockey Arena                   Trail
# 17             1.0              Pharmacy               Pet Store
# 18             3.0    Mexican Restaurant            Intersection
# 19             3.0     Health Food Store                     Pub
#
#    3rd Most Common Venue  4th Most Common Venue      5th Most Common Venue  \
# 0                  Hotel            Yoga Studio             Discount Store
# 1            Coffee Shop  Portuguese Restaurant                 Donut Shop
# 2                   Park                 Bakery                        Pub
# 3            Coffee Shop               Boutique         Miscellaneous Shop
# 4            Yoga Studio                    Bar                   Beer Bar
# 5                    NaN                    NaN                        NaN
# 6                  Diner         Discount Store        Distribution Center
# 7                   Café             Restaurant              Grocery Store
# 8     Athletics & Sports              Gastropub               Intersection
# 9    Japanese Restaurant        Bubble Tea Shop  Middle Eastern Restaurant
# 10                Bakery       Asian Restaurant        Japanese Restaurant
# 11                   NaN                    NaN                        NaN
# 12             Drugstore         Discount Store        Distribution Center
# 13                  Café             Restaurant              Grocery Store
# 14                  Park                    Spa                Video Store
# 15          Cocktail Bar                  Hotel             Cosmetics Shop
# 16                 Field           Tennis Court                      Diner
# 17          Liquor Store            Pizza Place                 Beer Store
# 18        Breakfast Spot      Electronics Store                       Bank
# 19                 Trail            Yoga Studio                 Donut Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0    Distribution Center               Dog Run      Doner Restaurant
# 1                  Diner        Discount Store   Distribution Center
# 2             Restaurant        Breakfast Spot               Theater
# 3           Carpet Store   Arts & Crafts Store     Accessories Store
# 4          Smoothie Shop        Sandwich Place         Burrito Place
# 5                    NaN                   NaN                   NaN
# 6                Dog Run      Doner Restaurant            Donut Shop
# 7           Dessert Shop             Bike Shop        Sandwich Place
# 8            Flea Market                  Bank  Gym / Fitness Center
# 9                  Hotel                  Café        Cosmetics Shop
# 10            Donut Shop        Discount Store   Distribution Center
# 11                   NaN                   NaN                   NaN
# 12               Dog Run      Doner Restaurant            Donut Shop
# 13          Dessert Shop             Bike Shop        Sandwich Place
# 14            Beer Store    Athletics & Sports          Dance Studio
# 15    Seafood Restaurant              Creperie            Restaurant
# 16        Discount Store   Distribution Center               Dog Run
# 17           Coffee Shop                  Café        Shopping Plaza
# 18            Restaurant        Medical Center   Rental Car Location
# 19                 Diner        Discount Store   Distribution Center
#
#     9th Most Common Venue 10th Most Common Venue
# 0              Donut Shop              Drugstore
# 1                 Dog Run       Doner Restaurant
# 2   Performing Arts Venue                Brewery
# 3   Vietnamese Restaurant        Coworking Space
# 4                    Café  Portuguese Restaurant
# 5                     NaN                    NaN
# 6     Dumpling Restaurant     Falafel Restaurant
# 7              Beer Store    Sporting Goods Shop
# 8     American Restaurant   Fast Food Restaurant
# 9    Fast Food Restaurant                Theater
# 10                Dog Run       Doner Restaurant
# 11                    NaN                    NaN
# 12    Dumpling Restaurant         Farmers Market
# 13             Beer Store    Sporting Goods Shop
# 14            Curling Ice             Donut Shop
# 15     Italian Restaurant                   Park
# 16       Doner Restaurant             Donut Shop
# 17       Doner Restaurant                  Diner
# 18            Yoga Studio    Distribution Center
# 19                Dog Run       Doner Restaurant

# %%
# Find Toronto

address = 'Toronto'

geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters+1)
ys = [i + x + (i*x)**2 for i in range(kclusters+1)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    if cluster.is_integer():
        cluster = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster],
        fill=True,
        fill_color=rainbow[cluster],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_35a4bdea9d4f4648b6cfbb2284ecaef3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_35a4bdea9d4f4648b6cfbb2284ecaef3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_35a4bdea9d4f4648b6cfbb2284ecaef3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_35a4bdea9d4f4648b6cfbb2284ecaef3%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
for i in range(kclusters+1):
    Cluster=Toronto_merged[Toronto_merged['Cluster Labels']==i]
    display(Cluster.head())
# Out:
#    Postal Code      Borough                                     Neighborhood  \
# 51         M1M  Scarborough  Cliffside, Cliffcrest, Scarborough Village West
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 51  43.716316 -79.239476             0.0                 Motel
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 51   American Restaurant             Drugstore                 Diner
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 51        Discount Store   Distribution Center               Dog Run
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 51      Doner Restaurant            Donut Shop    Dumpling Restaurant
#    Postal Code       Borough  \
# 8          M4B     East York
# 10         M6B    North York
# 17         M9C     Etobicoke
# 31         M6H  West Toronto
# 39         M2K    North York
#
#                                          Neighborhood   Latitude  Longitude  \
# 8                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 10                                          Glencairn  43.709577 -79.445073
# 17  Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 31                       Dufferin, Dovercourt Village  43.669005 -79.442259
# 39                                    Bayview Village  43.786947 -79.385975
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8              1.0           Pizza Place              Pharmacy
# 10             1.0                  Park           Pizza Place
# 17             1.0              Pharmacy             Pet Store
# 31             1.0                Bakery              Pharmacy
# 39             1.0                  Café                  Bank
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8     Athletics & Sports             Gastropub          Intersection
# 10                Bakery      Asian Restaurant   Japanese Restaurant
# 17          Liquor Store           Pizza Place            Beer Store
# 31             Pet Store           Music Venue                  Bank
# 39   Japanese Restaurant    Chinese Restaurant           Yoga Studio
#
#    6th Most Common Venue 7th Most Common Venue      8th Most Common Venue  \
# 8            Flea Market                  Bank       Gym / Fitness Center
# 10            Donut Shop        Discount Store        Distribution Center
# 17           Coffee Shop                  Café             Shopping Plaza
# 31           Supermarket                  Café  Middle Eastern Restaurant
# 39   Distribution Center               Dog Run           Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 8    American Restaurant   Fast Food Restaurant
# 10               Dog Run       Doner Restaurant
# 17      Doner Restaurant                  Diner
# 31                   Bar            Pizza Place
# 39            Donut Shop              Drugstore
#    Postal Code      Borough                            Neighborhood  \
# 12         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 12  43.784535 -79.160497             2.0                   Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 12           Yoga Studio             Drugstore        Discount Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 12   Distribution Center               Dog Run      Doner Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 12            Donut Shop   Dumpling Restaurant         Farmers Market
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.753259 -79.329656             3.0     Food & Drink Shop
# 1  43.725882 -79.315572             3.0          Hockey Arena
# 2  43.654260 -79.360636             3.0           Coffee Shop
# 3  43.718518 -79.464763             3.0        Clothing Store
# 4  43.662301 -79.389494             3.0           Coffee Shop
#
#     2nd Most Common Venue 3rd Most Common Venue  4th Most Common Venue  \
# 0                    Park                 Hotel            Yoga Studio
# 1       French Restaurant           Coffee Shop  Portuguese Restaurant
# 2                    Café                  Park                 Bakery
# 3  Furniture / Home Store           Coffee Shop               Boutique
# 4        Sushi Restaurant           Yoga Studio                    Bar
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Discount Store   Distribution Center               Dog Run
# 1            Donut Shop                 Diner        Discount Store
# 2                   Pub            Restaurant        Breakfast Spot
# 3    Miscellaneous Shop          Carpet Store   Arts & Crafts Store
# 4              Beer Bar         Smoothie Shop        Sandwich Place
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0      Doner Restaurant             Donut Shop              Drugstore
# 1   Distribution Center                Dog Run       Doner Restaurant
# 2               Theater  Performing Arts Venue                Brewery
# 3     Accessories Store  Vietnamese Restaurant        Coworking Space
# 4         Burrito Place                   Café  Portuguese Restaurant
#    Postal Code      Borough                                   Neighborhood  \
# 32         M1J  Scarborough                            Scarborough Village
# 35         M4J    East York  East Toronto, Broadview North (Old East York)
# 64         M9N         York                                         Weston
# 66         M2P   North York                                York Mills West
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 32  43.744734 -79.239476             4.0            Playground
# 35  43.685347 -79.338106             4.0          Intersection
# 64  43.706876 -79.518188             4.0     Convenience Store
# 66  43.752758 -79.400049             4.0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 32     Convenience Store           Yoga Studio             Drugstore
# 35                  Park     Convenience Store             Drugstore
# 64           Yoga Studio   Dumpling Restaurant        Discount Store
# 66     Convenience Store           Yoga Studio   Dumpling Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 32                 Diner        Discount Store   Distribution Center
# 35                 Diner        Discount Store   Distribution Center
# 64   Distribution Center               Dog Run      Doner Restaurant
# 66        Discount Store   Distribution Center               Dog Run
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 32               Dog Run      Doner Restaurant                   Donut Shop
# 35               Dog Run      Doner Restaurant                   Donut Shop
# 64            Donut Shop             Drugstore  Eastern European Restaurant
# 66      Doner Restaurant            Donut Shop                    Drugstore
#    Postal Code           Borough  \
# 21         M6E              York
# 52         M2M        North York
# 83         M4T   Central Toronto
# 85         M1V       Scarborough
# 91         M4W  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 21                                Caledonia-Fairbanks  43.689026 -79.453512
# 52                            Willowdale, Newtonbrook  43.789053 -79.408493
# 83                        Moore Park, Summerhill East  43.689574 -79.383160
# 85  Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 91                                           Rosedale  43.679563 -79.377529
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 21             5.0                  Park         Women's Store
# 52             5.0                  Park           Yoga Studio
# 83             5.0                  Park           Yoga Studio
# 85             5.0          Intersection                  Park
# 91             5.0                  Park                 Trail
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 21                  Pool           Yoga Studio             Drugstore
# 52   Dumpling Restaurant        Discount Store   Distribution Center
# 83   Dumpling Restaurant        Discount Store   Distribution Center
# 85            Playground             Drugstore                 Diner
# 91            Playground           Yoga Studio    Dim Sum Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 21                 Diner        Discount Store   Distribution Center
# 52               Dog Run      Doner Restaurant            Donut Shop
# 83               Dog Run      Doner Restaurant            Donut Shop
# 85        Discount Store   Distribution Center               Dog Run
# 91                 Diner        Discount Store   Distribution Center
#
#    9th Most Common Venue       10th Most Common Venue
# 21               Dog Run             Doner Restaurant
# 52             Drugstore  Eastern European Restaurant
# 83             Drugstore  Eastern European Restaurant
# 85      Doner Restaurant                   Donut Shop
# 91               Dog Run             Doner Restaurant
#   Postal Code      Borough    Neighborhood   Latitude  Longitude  \
# 6         M1B  Scarborough  Malvern, Rouge  43.806686 -79.194353
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 6             6.0  Fast Food Restaurant             Drugstore
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6                 Diner        Discount Store   Distribution Center
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 6               Dog Run      Doner Restaurant            Donut Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 6   Dumpling Restaurant     Falafel Restaurant
#    Postal Code          Borough Neighborhood   Latitude  Longitude  \
# 62         M5N  Central Toronto     Roselawn  43.711695 -79.416936
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 62             7.0                Garden           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 62            Donut Shop                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 62   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 62             Drugstore           Dessert Shop
#    Postal Code    Borough                                   Neighborhood  \
# 98         M8X  Etobicoke  The Kingsway, Montgomery Road, Old Mill North
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 98  43.653654 -79.506944             8.0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 98                 River           Yoga Studio      Doner Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 98    Dim Sum Restaurant                 Diner        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 98   Distribution Center               Dog Run             Donut Shop
#     Postal Code    Borough                                       Neighborhood  \
# 101         M8Y  Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
#
#       Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 101  43.636258 -79.498509             9.0        Baseball Field
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 101           Yoga Studio             Drugstore        Discount Store
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 101   Distribution Center               Dog Run      Doner Restaurant
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 101            Donut Shop   Dumpling Restaurant         Farmers Market
#    Postal Code      Borough  \
# 5          M9A    Etobicoke
# 11         M9B    Etobicoke
# 45         M2L   North York
# 95         M1X  Scarborough
#
#                                          Neighborhood   Latitude  Longitude  \
# 5             Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 11  West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 45                           York Mills, Silver Hills  43.757490 -79.374714
# 95                                        Upper Rouge  43.836125 -79.205636
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 5             10.0                   NaN                   NaN
# 11            10.0                   NaN                   NaN
# 45            10.0                   NaN                   NaN
# 95            10.0                   NaN                   NaN
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 5                    NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 45                   NaN                   NaN                   NaN
# 95                   NaN                   NaN                   NaN
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5                    NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 45                   NaN                   NaN                   NaN
# 95                   NaN                   NaN                   NaN
#
#    9th Most Common Venue 10th Most Common Venue
# 5                    NaN                    NaN
# 11                   NaN                    NaN
# 45                   NaN                    NaN
# 95                   NaN                    NaN
