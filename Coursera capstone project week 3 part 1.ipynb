# %% [markdown]
# Coursera capstone project week 3 part 1

# %%
# import needed libraries
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import csv
#!conda install -c conda-forge folium=0.5.0 --yes 
from pandas.io.json import json_normalize
import folium
import numpy as np
from sklearn.cluster import KMeans
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
import functools

# %%
# Scraping Wikipedia for information
url = "https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=1008658788"
# note: since the wikipedia page changed mid-project, I use a history version of the wikipedia page. 
html_content = requests.get(url).text
soup = bs(html_content, "lxml")

# Extracting information to dataframe
table = soup.find("table", attrs={"class": "wikitable"})

# identify columns
th = table.find_all("th")
headers = []
for x in th:
    headers.append(x.text.strip())
    
# identify rows  
tr = table.find_all("tr")
rows = []

# split elements into lists and remove empty elements
for x in tr[1:]:
    rows.append(x.text.split("\n"))
for x in rows:
    for y in x:
        x.remove('')
        
# Remove Not assigned        
df = pd.DataFrame(rows, columns = headers) 
df = df[df.Borough != 'Not assigned']
df.head(20)
# Out:
#    Postal Code           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 20         M3C        North York
# 21         M4C         East York
# 22         M5C  Downtown Toronto
# 23         M6C              York
# 26         M9C         Etobicoke
# 27         M1E       Scarborough
# 30         M4E      East Toronto
#
#                                         Neighbourhood
# 2                                           Parkwoods
# 3                                    Victoria Village
# 4                           Regent Park, Harbourfront
# ...

# %%
df.shape
# Out:
# (103, 3)
